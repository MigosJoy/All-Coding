# %% [markdown]
# # 4.8 Exceptions and Assertions - 11/16
#
# * What happens when procedure execution hits an unexpected condition?
# * Get an exception to what was expected
#
# Types of Exceptions:
# * SyntaxError: Python can't parse program
# * NameError: local or global name not found
# * AttributeError: attribute reference fails
# * TypeError: operand doesn't have correct type
# * ValueError: operand type okay, but value is illegal
# * IOError: IO system reports malfunction (e.g. file not found)
#
# *What to do with Exceptions?*
#
# * Fail silently
#     * bad idea, user gets no warning
# * Return an "error" value
#     * what value to choose
#     * complicates codes
# * Stop execution, signal error condition
#     * In Python: raise an exception
#
#     ![image.png](attachment:image.png)
#
# *Dealing with exception*
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# *Other Exceptions*
# * Else:
#     * body of else clause is executed if no exceptions are raised in try clause
# * Finally:
#     * body of finally clause executed regardless of what happens in try clause
#     * if try clause raises exception, the finally clause will execute even if there is no matching except clause
#     * useful for clean-up code that should be run no matter what else happened (e.g. close a file)

# %% [markdown]
# #### <ins>Exceptions Examples</ins>
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### <ins>Exceptions as Control Flow</ins>
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# #### <ins>Assertions</ins>
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# *Assertions as Defensive Programming*
# * Don't allow to control response to unexpected conditions
# * Ensure that execution halts whenever an expected condition is not met
# * Can be used to check inputs, outputs, and invariants
# * Can help detect bugs more quickly and with less pain
#
# *Where to use Assertions?*
# * Goal is to spot bugs as soon as introduced
# * Use as a supplement to tests
# * Raise exceptions if users supplies bad data
# * Use assertions to:
#     * check types of arguments or values
#     * check that invariants on data structures are met
#     * check constraints on return values
#     * check for violations of constraints on procedure (e.g. no duplicates in a list)
