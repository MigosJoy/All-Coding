# %% [markdown]
# # 3.6 Dictionaries - Started 11/9

# %% [markdown]
# *<ins>Dictionaries</ins>*
#
# *Example*
# * So far, can store using separate lists for every info
#     * names = ['Alice', 'Bob', 'Cathy', 'Dan']
#     * grades = ['B', 'A', 'D', 'B']
#     * course = [2.00, 6.0001, 20.002, 9.01]
#
# * A separate list for each item
# * Each list must have the same length
# * Info stored across multiple lists at same index, each index refers to info for a different person
#
# *How to Update/Retrieve Student Info*
#
# ![image.png](attachment:image.png)
#
# * Messy if have a lot of differnt info to keep track of
# * Must maintain many lists and pass them as arguments
# * Must always index using integers
# * Must remember to change multiple lists
#
# *A Better and Cleaner Way - A Dictionary*
# * Nice to index item of interest directly (not always int)
# * Nice to use onee data structure, no separate lists
#
# ![image-2.png](attachment:image-2.png)
#
# *A Python Dictionary*
# * Store pairs of data
#     * Key
#     * Value
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# *Dictionary Lookup*
# * Similar to indexing into a list
# * looks up the key
# * returns the value associated with that key
# * If the key is not in the dictionary, get an error
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# *Dictionary Keys and Values*
# * Values
#     * any type (immutable and mutable)
#     * can be duplicates
#     * dictionary values can be lists, even other dictionaries
#
# * Keys
#     * Must be unique
#     * Immutable type (int, float, string, tuple, bool)
#         * Actually need an object that is hashable, but think of it as immutable as all immutable types are hashable
#     * Careful with *float* type as key
# * No order to keys or values
#
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# *<ins>Example with a Dictionary</ins>*
#
# *3 Functions to Analyze Song Lyrics*
# 1. Create a frequency dictionary that maps each word in the lyrics to the number of times it occurs
# 2. Find the most common word in the lyrics
#     * Use a list, in case more than one word
#     * return a tuple (list,int) for (words_list,highest_freq)
# 3. Find all words that occur a user-specified number of times
#     * return a list of tuples, each tuple (list,int) contains a word and its frequency
#     * IDEA: From song dictionary, find most frequent word. Delete most common word. Repeat. It works bc you are mutating the song dictionary
#
# *Creating a Dictionary*
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# *<ins>Fibonacci and Dictionaries</ins>*
#
# *Fibonacci Recursive Code*
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# *Fibonacci with a Dictionary*
#
# ![image-3.png](attachment:image-3.png)
#
# **Sometimes called memoization**

# %% [markdown]
# *<ins>Global Variables</ins>*
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
