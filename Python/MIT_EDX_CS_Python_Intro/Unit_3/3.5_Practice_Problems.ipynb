# %% [markdown]
# # 3.5 Tuples and Lists Practice Problems - Started 11/8

# %% [markdown]
# #### <ins>Exercise 1</ins>
#
# For each of the expressions below, specify its type and value. If it generates an error, select type 'NoneType' and put the word 'error' in the box for the value.
#
# Assume we've made the following assignment:
#
# x = (1, 2, (3, 'John', 4), 'Hi')
#
# When a tuple has only one element, you must specify it as follows: (elt,). Here is an example shell session that illustrates the difference:

# %%
>>> tup1 = (5)
>>> print(tup1)
5
>>> type(tup1)
<type 'int'>
>>> tup2 = (5,)
>>> print(tup2)
(5,)
>>> type(tup2)
<type 'tuple'>

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### <ins>Exercise 2 - Odd Tuples</ins>
#
# Write a procedure called oddTuples, which takes a tuple as input, and returns a new tuple as output, where every other element of the input tuple is copied, starting with the first one. So if test is the tuple ('I', 'am', 'a', 'test', 'tuple'), then evaluating oddTuples on this input would return the tuple ('I', 'a', 'tuple').

# %%
x = (1,2,3,4,5)
y = x[::2]
print(y)
# Out:
# (1, 3, 5)

# %%
def oddTuples(aTup):
    '''
    aTup: a tuple
    returns: tuple, every other element of aTup.
    '''
    bTup = aTup[::2]
    return bTup

z = oddTuples(x)
print(z)
z == y
z + y
# Out:
# (1, 3, 5)
# (1, 3, 5, 1, 3, 5)

# %% [markdown]
# #### <ins>Exercise 2 - List</ins>

# %%
listA = [1, 4, 3, 0]
listB = ['x','z','t','q']

# %%
listA.sort
# Out:
# <function list.sort(*, key=None, reverse=False)>

# %%
listA.sort()

# %%
print(listA)
# Out:
# [0, 1, 3, 4]

# %%
listB.sort()
listB.pop()
listA.insert(0,100)
listA.remove(3)
listA.append(7)
listA
# Out:
# [100, 0, 1, 4, 7]

# %%
listA.extend([4,1,6,3,4])
listA
# Out:
# [100, 0, 1, 4, 7, 4, 1, 6, 3, 4]

# %%
listA.index(1)
# Out:
# 2

# %% [markdown]
# #### <ins>Exercise - Apply to Each</ins>

# %%
def applyToEach(L, f):
    for i in range(len(L)):
        L[i] = f(L[i])

# %%
testList = [1, -4, 8, -9]
print(testList)
# Out:
# [1, -4, 8, -9]

# %%
def absvalue(x):
    return abs(x)

applyToEach(testList,absvalue)
print(testList)
# Out:
# [1, 4, 8, 9]

# %%
def addone(x):
    return x+1

applyToEach(testList,addone)
print(testList)
# Out:
# [2, -3, 9, -8]

# %%
def squared(x):
    return x**2

applyToEach(testList,squared)
print(testList)
# Out:
# [1, 16, 64, 81]
